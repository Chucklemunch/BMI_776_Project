# %%
import requests, sys, json
import pandas as pd
import pickle
import mygene

# %%
### BioGRID access key
BIOGRID_ACCESS_KEY = 'a207ffa23db79e55a7d7a5a69b79f0c9'

# %%
server = "https://rest.ensembl.org"

# %%
with open('../Results/GENIE3/SARS-CoV-2/ranked_interaction_list_500.txt', 'r') as f:
    interactions = pd.read_table(f, header=None)
    interactions = interactions.rename(columns = {0 : 'gene1', 1 : 'gene2', 2 : 'score'})

# %%
with open('../Results/GENIE3/SARS-CoV-2/interactions_dataframe.pickle', 'wb') as f:
    pickle.dump(interactions, f)

# %%
with open('../Results/GENIE3/SARS-CoV-2/interactions_dataframe.pickle', 'rb') as f:
    interactions = pickle.load(f)

# %%
interactions
# Out:
#                   gene1            gene2     score
# 0       ENSG00000200336  ENSG00000201695  0.102868
# 1       ENSG00000201695  ENSG00000200336  0.085720
# 2       ENSG00000273590  ENSG00000205670  0.081955
# 3       ENSG00000205670  ENSG00000273590  0.077385
# 4       ENSG00000160201  ENSG00000275895  0.072684
# ...                 ...              ...       ...
# 249495  ENSG00000137673  ENSG00000201965  0.000000
# 249496  ENSG00000206918  ENSG00000199546  0.000000
# 249497  ENSG00000252714  ENSG00000240665  0.000000
# 249498  ENSG00000228078  ENSG00000202354  0.000000
# 249499  ENSG00000229230  ENSG00000200356  0.000000
#
# [249500 rows x 3 columns]

# %%
with open('../Data/SARS-CoV-2/highly_variable_genes_503.pickle', 'rb') as f:
    genes = pickle.load(f)

genes
# Out:
# ['ENSG00000007171',
#  'ENSG00000012223',
#  'ENSG00000012817',
#  'ENSG00000019186',
#  'ENSG00000022556',
#  'ENSG00000036448',
#  'ENSG00000041982',
#  'ENSG00000054690',
#  'ENSG00000064225',
#  'ENSG00000067048',
#  'ENSG00000067646',
#  'ENSG00000073756',
#  'ENSG00000074410',
#  'ENSG00000078081',
#  'ENSG00000081041',
#  'ENSG00000087495',
#  'ENSG00000089127',
#  'ENSG00000091137',
#  'ENSG00000091513',
#  'ENSG00000091986',
#  'ENSG00000093072',
#  'ENSG00000099725',
#  'ENSG00000099860',
#  'ENSG00000100033',
#  'ENSG00000100985',
#  'ENSG00000102854',
#  'ENSG00000103187',
#  'ENSG00000105894',
#  'ENSG00000106538',
#  'ENSG00000106560',
#  'ENSG00000107201',
#  'ENSG00000110195',
#  'ENSG00000110446',
#  'ENSG00000111331',
#  'ENSG00000111335',
#  'ENSG00000112303',
#  'ENSG00000113924',
#  'ENSG00000114115',
#  'ENSG00000114374',
#  'ENSG00000115415',
#  'ENSG00000117407',
#  'ENSG00000117643',
#  'ENSG00000117983',
#  'ENSG00000118849',
#  'ENSG00000119917',
# ...

# %%
server = "https://rest.ensembl.org"

ensembl_gene_dict = {}

# Get gene names for Ensembl names
for i, gene in enumerate(genes):
    print(i+1, gene)
    
    ext = f'/xrefs/id/{gene}?'

    r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})

    # Dealing with bad requests: remove gene
    if not r.ok:
        drop_interaction = True
        print(f'bad request for {gene}')
        ensembl_gene_dict[gene] = None
    else:
        # Get gene name from query response
        decoded = r.json()
        gene_name = decoded[-1]['display_id']
        ensembl_gene_dict[gene] = gene_name

        
ensembl_gene_dict
# Out:
# 1 ENSG00000007171
# 2 ENSG00000012223
# 3 ENSG00000012817
# 4 ENSG00000019186
# 5 ENSG00000022556
# 6 ENSG00000036448
# 7 ENSG00000041982
# 8 ENSG00000054690
# 9 ENSG00000064225
# 10 ENSG00000067048
# 11 ENSG00000067646
# 12 ENSG00000073756
# 13 ENSG00000074410
# 14 ENSG00000078081
# 15 ENSG00000081041
# 16 ENSG00000087495
# 17 ENSG00000089127
# 18 ENSG00000091137
# 19 ENSG00000091513
# 20 ENSG00000091986
# 21 ENSG00000093072
# 22 ENSG00000099725
# 23 ENSG00000099860
# 24 ENSG00000100033
# 25 ENSG00000100985
# 26 ENSG00000102854
# 27 ENSG00000103187
# 28 ENSG00000105894
# 29 ENSG00000106538
# 30 ENSG00000106560
# 31 ENSG00000107201
# 32 ENSG00000110195
# 33 ENSG00000110446
# 34 ENSG00000111331
# 35 ENSG00000111335
# 36 ENSG00000112303
# 37 ENSG00000113924
# 38 ENSG00000114115
# 39 ENSG00000114374
# 40 ENSG00000115415
# 41 ENSG00000117407
# 42 ENSG00000117643
# 43 ENSG00000117983
# 44 ENSG00000118849
# 45 ENSG00000119917
# 46 ENSG00000119922
# 47 ENSG00000121552
# 48 ENSG00000122861
# ...

# %%
with open('../Data/SARS-CoV-2/ensembl_gene_dict.pickle', 'wb') as f:
    pickle.dump(ensembl_gene_dict, f)

# %%
### Getting gene names for each interaction ###
gene1_names = []
gene2_names = []

for gene1, gene2 in interactions[['gene1', 'gene2']].values:
    gene1_names.append(ensembl_gene_dict[gene1])
    gene2_names.append(ensembl_gene_dict[gene2])

interactions['gene1_name'] = pd.Series(gene1_names)
interactions['gene2_name'] = pd.Series(gene2_names)

interactions
# Out:
#                   gene1            gene2     score    gene1_name    gene2_name
# 0       ENSG00000200336  ENSG00000201695  0.102868       5S_rRNA       5S_rRNA
# 1       ENSG00000201695  ENSG00000200336  0.085720       5S_rRNA       5S_rRNA
# 2       ENSG00000273590  ENSG00000205670  0.081955  LOC102723553  LOC102723553
# 3       ENSG00000205670  ENSG00000273590  0.077385  LOC102723553  LOC102723553
# 4       ENSG00000160201  ENSG00000275895  0.072684  LOC102724594  LOC102724594
# ...                 ...              ...       ...           ...           ...
# 249495  ENSG00000137673  ENSG00000201965  0.000000          MMP7         Y_RNA
# 249496  ENSG00000206918  ENSG00000199546  0.000000            U6         Y_RNA
# 249497  ENSG00000252714  ENSG00000240665  0.000000       5S_rRNA        LSP1P2
# 249498  ENSG00000228078  ENSG00000202354  0.000000         HLA-U          RNY3
# 249499  ENSG00000229230  ENSG00000200356  0.000000         MT1P3            U6
#
# ...

# %%
with open('../Results/GENIE3/SARS-CoV-2/interactions_dataframe_with_names.pickle', 'wb') as f:
    pickle.dump(interactions, f)

# %%
with open('../Results/GENIE3/SARS-CoV-2/interactions_dataframe_with_names.pickle', 'rb') as f:
    interactions = pickle.load(f)

interactions
# Out:
#                   gene1            gene2     score    gene1_name    gene2_name
# 0       ENSG00000200336  ENSG00000201695  0.102868       5S_rRNA       5S_rRNA
# 1       ENSG00000201695  ENSG00000200336  0.085720       5S_rRNA       5S_rRNA
# 2       ENSG00000273590  ENSG00000205670  0.081955  LOC102723553  LOC102723553
# 3       ENSG00000205670  ENSG00000273590  0.077385  LOC102723553  LOC102723553
# 4       ENSG00000160201  ENSG00000275895  0.072684  LOC102724594  LOC102724594
# ...                 ...              ...       ...           ...           ...
# 249495  ENSG00000137673  ENSG00000201965  0.000000          MMP7         Y_RNA
# 249496  ENSG00000206918  ENSG00000199546  0.000000            U6         Y_RNA
# 249497  ENSG00000252714  ENSG00000240665  0.000000       5S_rRNA        LSP1P2
# 249498  ENSG00000228078  ENSG00000202354  0.000000         HLA-U          RNY3
# 249499  ENSG00000229230  ENSG00000200356  0.000000         MT1P3            U6
#
# ...

# %%
### With help of ChatGPT, get mapping of Ensembl IDs to entrezgene
# https://docs.mygene.info/projects/mygene-py/en/latest/#mygene.MyGeneInfo.querymany

ensembl_entrez_dict = {}

# Initialize MyGene.info
mg = mygene.MyGeneInfo()

# Example Ensembl gene IDs
ensembl_ids = genes

result = mg.querymany(ensembl_ids, scopes="ensembl.gene", fields="entrezgene", species="human")

for item in result:
    ensembl_gene = item['query']
    entrez_gene = item.get('entrezgene', None)

    ensembl_entrez_dict[ensembl_gene] = entrez_gene

ensembl_entrez_dict
# Out:
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# 2 input query terms found dup hits:	[('ENSG00000273730', 10), ('ENSG00000275757', 10)]
# 9 input query terms found no hit:	['ENSG00000203812', 'ENSG00000225932', 'ENSG00000228648', 'ENSG00000269899', 'ENSG00000269900', 'ENS
# {'ENSG00000007171': '4843',
#  'ENSG00000012223': '4057',
#  'ENSG00000012817': '8284',
#  'ENSG00000019186': '1591',
#  'ENSG00000022556': '55655',
#  'ENSG00000036448': '9172',
#  'ENSG00000041982': '3371',
#  'ENSG00000054690': '57475',
#  'ENSG00000064225': '10402',
#  'ENSG00000067048': '8653',
#  'ENSG00000067646': '7544',
#  'ENSG00000073756': '5743',
#  'ENSG00000074410': '771',
#  'ENSG00000078081': '27074',
#  'ENSG00000081041': '2920',
#  'ENSG00000087495': '116154',
#  'ENSG00000089127': '4938',
#  'ENSG00000091137': '5172',
#  'ENSG00000091513': '7018',
#  'ENSG00000091986': '151887',
# ...

# %%
with open('../Data/SARS-CoV-2/ensembl_entrez_dict.pickle', 'wb') as f:
    pickle.dump(ensembl_entrez_dict, f)

# %%
### Getting entrez gene ids for each interaction ###
gene1_names = []
gene2_names = []

for gene1, gene2 in interactions[['gene1', 'gene2']].values:
    gene1_names.append(ensembl_entrez_dict[gene1])
    gene2_names.append(ensembl_entrez_dict[gene2])

interactions['gene1_entrez'] = pd.Series(gene1_names)
interactions['gene2_entrez'] = pd.Series(gene2_names)

interactions
# Out:
#                   gene1            gene2     score    gene1_name  \
# 0       ENSG00000200336  ENSG00000201695  0.102868       5S_rRNA
# 1       ENSG00000201695  ENSG00000200336  0.085720       5S_rRNA
# 2       ENSG00000273590  ENSG00000205670  0.081955  LOC102723553
# 3       ENSG00000205670  ENSG00000273590  0.077385  LOC102723553
# 4       ENSG00000160201  ENSG00000275895  0.072684  LOC102724594
# ...                 ...              ...       ...           ...
# 249495  ENSG00000137673  ENSG00000201965  0.000000          MMP7
# 249496  ENSG00000206918  ENSG00000199546  0.000000            U6
# 249497  ENSG00000252714  ENSG00000240665  0.000000       5S_rRNA
# 249498  ENSG00000228078  ENSG00000202354  0.000000         HLA-U
# 249499  ENSG00000229230  ENSG00000200356  0.000000         MT1P3
#
#           gene2_name gene1_entrez gene2_entrez
# 0            5S_rRNA    106480763    106865375
# 1            5S_rRNA    106865375    106480763
# ...

# %%
with open('../Results/GENIE3/SARS-CoV-2/interactions_dataframe_with_entrez.pickle', 'wb') as f:
    pickle.dump(interactions, f)
