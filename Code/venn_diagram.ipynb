# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib_venn import venn2, venn3
import pickle

# %%
import os
print(os.getcwd())
# Out:
# /home/ckotula/BMI_776_Project/Code/network_comparison

# %%
genie3 = pd.read_csv('../Results/Undirected_Results/GENIE3_net_gene_symbols_undirected.tsv', sep='\t')
grnboost2 = pd.read_csv('../Results/Undirected_Results/GRNBoost2_net_gene_symbols_undirected.tsv', sep='\t')
pidc = pd.read_csv('../Results/Undirected_Results/PIDC_net_gene_symbols_undirected.tsv', sep='\t')


print(genie3.columns.tolist())
# Out:
# ['TF', 'target', 'importance']

# %%
# --- Load your three adjacency matrices ---
# Assuming each is a square DataFrame with gene names as index/columns
genie3 = pd.read_csv('../Results/Undirected_Results/GENIE3_net_gene_symbols_undirected.tsv', sep='\t')
grnboost2 = pd.read_csv('../Results/Undirected_Results/GRNBoost2_net_gene_symbols_undirected.tsv', sep='\t')
pidc = pd.read_csv('../Results/Undirected_Results/PIDC_net_gene_symbols_undirected.tsv', sep='\t')


# --- Convert each matrix to a set of undirected interactions ---
def edge_set(df):
    return set(frozenset((row['TF'], row['target'])) for _, row in df.iterrows())

edges_genie3 = edge_set(genie3)
edges_grnboost2 = edge_set(grnboost2)
edges_pidc = edge_set(pidc)

# --- Plot Venn Diagram ---
venn3(
    [edges_genie3, edges_grnboost2, edges_pidc],
    set_labels=('GENIE3', 'GRNBoost2', 'PIDC')
)

plt.title("Venn Diagram of Gene-Gene Interactions")
plt.show()

# %%
print("GENIE3:", len(edges_genie3))
print("GRNBoost2:", len(edges_grnboost2))
print("PIDC:", len(edges_pidc))
# Out:
# GENIE3: 62845
# GRNBoost2: 31843
# PIDC: 62835

# %%
# Get sizes of sets
only_genie3 = edges_genie3 - edges_grnboost2 - edges_pidc
only_grnboost2 = edges_grnboost2 - edges_genie3 - edges_pidc
only_pidc = edges_pidc - edges_genie3 - edges_grnboost2
shared_all = edges_genie3 & edges_grnboost2 & edges_pidc
genie3_pidc = edges_genie3 & edges_pidc - shared_all
genie3_grnboost2 = edges_genie3 & edges_grnboost2 - shared_all
grnboost2_pidc = edges_grnboost2 & edges_pidc - shared_all

# Print a simple table
summary = {
    "Only GENIE3": len(only_genie3),
    "Only GRNBoost2": len(only_grnboost2),
    "Only PIDC": len(only_pidc),
    "GENIE3 ∩ PIDC": len(genie3_pidc),
    "GENIE3 ∩ GRNBoost2": len(genie3_grnboost2),
    "GRNBoost2 ∩ PIDC": len(grnboost2_pidc),
    "All 3": len(shared_all)
}

for k, v in summary.items():
    print(f"{k:<20}: {v}")
# Out:
# Only GENIE3         : 10
# Only GRNBoost2      : 0
# Only PIDC           : 0
# GENIE3 ∩ PIDC       : 30992
# GENIE3 ∩ GRNBoost2  : 0
# GRNBoost2 ∩ PIDC    : 0
# All 3               : 31843

# %%
def top_k_edges(df, k=10000):
    df_top = df.nlargest(k, 'importance')
    return set(frozenset((row['TF'], row['target'])) for _, row in df_top.iterrows())

k = 10000  # or 5000, 20000, etc.
edges_top_genie3 = top_k_edges(genie3, k)
edges_top_grnboost2 = top_k_edges(grnboost2, k)
edges_top_pidc = top_k_edges(pidc, k)

# Plot Venn
venn3(
    [edges_top_genie3, edges_top_grnboost2, edges_top_pidc],
    set_labels=(f'GENIE3 Top {k}', f'GRNBoost2 Top {k}', f'PIDC Top {k}')
)
plt.title(f"Top {k} Interactions Overlap")
plt.show()

# %%
# --- Function to get top-k undirected edges ---
def top_k_edges(df, k=10000):
    df_top = df.nlargest(k, 'importance')  # top k by importance
    return set(frozenset((row['TF'], row['target'])) for _, row in df_top.iterrows())

# --- Get top 10,000 edges from each method ---
k = 10000
edges_genie3_top = top_k_edges(genie3, k)
edges_grnboost2_top = top_k_edges(grnboost2, k)
edges_pidc_top = top_k_edges(pidc, k)

# --- Compute overlaps ---
only_genie3 = edges_genie3_top - edges_grnboost2_top - edges_pidc_top
only_grnboost2 = edges_grnboost2_top - edges_genie3_top - edges_pidc_top
only_pidc = edges_pidc_top - edges_genie3_top - edges_grnboost2_top
shared_all = edges_genie3_top & edges_grnboost2_top & edges_pidc_top
genie3_pidc = (edges_genie3_top & edges_pidc_top) - shared_all
genie3_grnboost2 = (edges_genie3_top & edges_grnboost2_top) - shared_all
grnboost2_pidc = (edges_grnboost2_top & edges_pidc_top) - shared_all

# --- Print result summary ---
summary = {
    "Only GENIE3": len(only_genie3),
    "Only GRNBoost2": len(only_grnboost2),
    "Only PIDC": len(only_pidc),
    "GENIE3 ∩ PIDC": len(genie3_pidc),
    "GENIE3 ∩ GRNBoost2": len(genie3_grnboost2),
    "GRNBoost2 ∩ PIDC": len(grnboost2_pidc),
    "All 3": len(shared_all)
}

print(f"\n=== Top {k} Edge Overlap Summary ===")
for k, v in summary.items():
    print(f"{k:<22}: {v}")
# Out:
# === Top 10000 Edge Overlap Summary ===
# Only GENIE3           : 1479
# Only GRNBoost2        : 4057
# Only PIDC             : 5404
# GENIE3 ∩ PIDC         : 970
# GENIE3 ∩ GRNBoost2    : 2317
# GRNBoost2 ∩ PIDC      : 1036
# All 3                 : 2590

# %%
def extract_genes(edge_set):
    genes = set()
    for edge in edge_set:
        genes.update(edge)
    return genes

genes_only_genie3 = extract_genes(only_genie3)
genes_only_grnboost2 = extract_genes(only_grnboost2)
genes_only_pidc = extract_genes(only_pidc)

print("Unique genes in GENIE3:", len(genes_only_genie3))
print("Unique genes in grnboost2:", len(genes_only_grnboost2))
print("Unique genes in pidc:", len(genes_only_pidc))
# Out:
# Unique genes in GENIE3: 335
# Unique genes in grnboost2: 355
# Unique genes in pidc: 355

# %%
import networkx as nx

def build_graph(edges):
    G = nx.Graph()
    # Only add edges that are actually between two different genes
    clean_edges = [tuple(e) for e in edges if len(e) == 2]
    G.add_edges_from(clean_edges)
    return G


for name, edges in [('GENIE3', edges_genie3_top), ('GRNBoost2', edges_grnboost2_top), ('PIDC', edges_pidc_top)]:
    G = build_graph(edges)
    print(f"\n{name} Network:")
    print("Nodes:", G.number_of_nodes())
    print("Edges:", G.number_of_edges())
    print("Average Degree:", sum(dict(G.degree()).values()) / G.number_of_nodes())
# Out:
# GENIE3 Network:
# Nodes: 355
# Edges: 7351
# Average Degree: 41.414084507042254
#
# GRNBoost2 Network:
# Nodes: 355
# Edges: 10000
# Average Degree: 56.33802816901409
#
# PIDC Network:
# Nodes: 355
# Edges: 10000
# Average Degree: 56.33802816901409

# %% [markdown]
# # Creating Venn Diagram for accurate predicted interactions

# %%
with open('../Results/found_interactions_dict_500.pickle', 'rb') as f:
    found_interactions = pickle.load(f)

found_interactions
# Out:
# {'GENIE3': [('DDIT3', 'GADD45B'),
#   ('CCN1', 'FOS'),
#   ('ECM1', 'HOPX'),
#   ('HLA-DQA1', 'HLA-DQB1'),
#   ('CXCL10', 'CXCL11'),
#   ('OAS2', 'STAT1'),
#   ('HLA-H', 'LSP1'),
#   ('KRT17', 'THBS1'),
#   ('CXCL2', 'CXCL8'),
#   ('KRT17', 'KRT6A'),
#   ('CTNNA1-AS1', 'PTN'),
#   ('IFIT3', 'ISG15'),
#   ('MX1', 'SAMD9L'),
#   ('GMPR', 'OASL'),
#   ('LOC107987423', 'PTN'),
#   ('IFIT1', 'IFIT3'),
#   ('ADA2', 'F8A3'),
#   ('IFIT3', 'SAMD9L'),
#   ('IFI44L', 'STAT1'),
#   ('SERPINA1', 'STATH'),
#   ('KRT14', 'KRT6A'),
#   ('C4B', 'TGM2'),
#   ('SERPINA3', 'TGM2'),
#   ('ECM1', 'SPRR3'),
#   ('IFIT1', 'STAT1'),
#   ('IFIT3', 'MX2'),
#   ('HSH2D', 'STAT1'),
#   ('HSH2D', 'TRIM5'),
#   ('IFIT1', 'OAS2'),
#   ('DDIT3', 'PLAU'),
#   ('CMPK2', 'IFIT3'),
#   ('MX2', 'RSAD2'),
#   ('NKX2-1', 'SFTA3'),
#   ('IFIT1', 'ISG15'),
#   ('MUC5B', 'TGM2'),
#   ('IFIT2', 'ISG15'),
#   ('MX2', 'OASL'),
#   ('GMPR', 'ISG15'),
#   ('LAMP3', 'MX1'),
#   ('KCNMA1', 'MAN1C1'),
#   ('MX1', 'OAS2'),
#   ('FAM3B', 'TGM2'),
#   ('IFIT3', 'RIGI'),
#   ('CES1', 'LOC107987423'),
#   ('IFIT3', 'MX1'),
#   ('EPSTI1', 'IFIT3'),
#   ('FOS', 'GADD45B'),
#   ('RARRES1', 'TGM2'),
#   ('MX2', 'SAMD9'),
#   ('IFITM1', 'OAS2'),
#   ('ADA2', 'RPL13P12'),
#   ('ISG15', 'OAS1'),
#   ('DDX60', 'STAT1'),
#   ('FAM3B', 'NKX2-1'),
#   ('ISG15', 'MX2'),
#   ('IFIT3', 'OAS1'),
#   ('IFITM1', 'LAMP3'),
#   ('LOC128966702', 'MYOM2'),
#   ('IFIT3', 'OASL'),
#   ('NOS2', 'PLEKHH1'),
#   ('CXCL2', 'PTGS2'),
#   ('HLA-DOA', 'TNNT3'),
#   ('IFIT1', 'MX1'),
#   ('KRT17', 'KRT6B'),
#   ('PLAU', 'PTGS2'),
#   ('ADA2', 'CNTNAP3C'),
#   ('CMPK2', 'ISG15'),
#   ('ECM1', 'KRT13'),
#   ('MX1', 'STAT1'),
#   ('KRT6A', 'THBS1'),
#   ('IFIT3', 'OAS2'),
#   ('CXCL10', 'IFIT3'),
#   ('HSH2D', 'MX2'),
#   ('CA12', 'NOS2'),
#   ('KCNMA1', 'NOS2'),
#   ('ISG15', 'RSAD2'),
#   ('ISG15', 'MX1'),
#   ('CHP2', 'LINC01291'),
#   ('C4B', 'KCNMA1'),
#   ('GMPR', 'MX2'),
#   ('MX1', 'RIGI'),
#   ('MX1', 'OAS3'),
#   ('IFITM1', 'TRIM5'),
#   ('MX2', 'OAS1'),
#   ('MX2', 'RIGI'),
#   ('GMPR', 'OAS1'),
#   ('CSTA', 'EMP1'),
#   ('HSH2D', 'MX1'),
#   ('IFI44L', 'MX1'),
#   ('MX2', 'SAMD9L'),
#   ('DDX60', 'MX1'),
#   ('C1orf141', 'PTN'),
#   ('GSTA2', 'TGM2'),
#   ('KCNMA1', 'SAA2-SAA4'),
#   ('CMPK2', 'MX1'),
#   ('CHP2', 'MYOM2'),
#   ('C1S', 'GDF15'),
#   ('MX1', 'MX2'),
#   ('ISG15', 'OAS3'),
#   ('ISG15', 'OASL'),
#   ('IFIT3', 'OAS3'),
#   ('LGALS7B', 'NOS2'),
#   ('IFI44L', 'IFIT3'),
#   ('TGM2', 'UNC93B2'),
#   ('C6orf52', 'PROS1'),
#   ('MX2', 'OAS2'),
#   ('ISG15', 'STAT1'),
#   ('CD68', 'IFIT3'),
#   ('IFIT1', 'IFIT2'),
#   ('FOS', 'GDF15'),
#   ('CD68', 'GMPR'),
#   ('APOBEC3A_B', 'ECM1'),
#   ('NOS2', 'UNC93B2'),
#   ('IFITM1', 'MX1'),
#   ('HP', 'NOS2'),
#   ('ADA2', 'PAX8-AS1'),
#   ('HSH2D', 'IFIT3'),
#   ('KRT16', 'KRT6B'),
#   ('KCNMA1', 'PTMAP5'),
#   ('IFIT3', 'STAT1'),
#   ('MX1', 'OAS1'),
#   ('CXCL8', 'PTGS2')],
#  'GRNBoost2': [('LSP1', 'TTTY15'),
#   ('NLGN4Y', 'PTN'),
#   ('CES1', 'TXLNGY'),
#   ('PTN', 'TXLNGY'),
#   ('CES1', 'EIF1AY'),
#   ('KDM5D', 'PTN'),
#   ('CES1', 'TTTY15'),
#   ('EIF1AY', 'PTN'),
#   ('GMPR', 'IFIT3'),
#   ('DDX3Y', 'PTN'),
#   ('LSP1', 'RPS4Y1'),
#   ('PTN', 'TTTY14'),
#   ('CES1', 'RPS4Y1'),
#   ('PTN', 'RPS4Y1'),
#   ('GMPR', 'OASL'),
#   ('GMPR', 'OAS1'),
#   ('MX2', 'RIGI'),
#   ('CXCL2', 'PTGS2'),
#   ('IFIT1', 'IFIT3'),
#   ('KRT14', 'KRT6A'),
#   ('HLA-DQA1', 'HLA-DQB1'),
#   ('ECM1', 'NOS2'),
#   ('KCNMA1', 'PTMAP5'),
#   ('ISG15', 'MX1'),
#   ('ISG15', 'MX2'),
#   ('CTNNA1-AS1', 'PTN'),
#   ('CHP2', 'LINC01291'),
#   ('TGM2', 'TTTY15'),
#   ('PTGS2', 'TLR2'),
#   ('MX2', 'OASL'),
#   ('LINC00278', 'PTN'),
#   ('ECM1', 'LINC00665'),
#   ('IFIT3', 'RSAD2'),
#   ('ADA2', 'RPL13P12'),
#   ('OAS2', 'TRIM5'),
#   ('GMPR', 'ISG15'),
#   ('NKX2-1', 'SFTA3'),
#   ('LSP1', 'RPL13P12'),
#   ('KRT6A', 'THBS1'),
#   ('MX2', 'RSAD2'),
#   ('KRT17', 'THBS1'),
#   ('CCN1', 'FOS'),
#   ('OAS2', 'STAT1'),
#   ('C4B', 'TGM2'),
#   ('CXCL10', 'IFIT3'),
#   ('EPSTI1', 'IFITM1'),
#   ('NOS2', 'PLEKHH1'),
#   ('KRT16', 'KRT6B'),
#   ('IFITM1', 'OAS1'),
#   ('CES1', 'UTY'),
#   ('PROS1', 'TIMP4'),
#   ('KRT17', 'KRT6A'),
#   ('NKX2-1', 'RARRES1'),
#   ('DDX60', 'STAT1'),
#   ('MX1', 'RIGI'),
#   ('CD68', 'MX2'),
#   ('MX2', 'OAS1'),
#   ('DOC2B', 'TRIM31'),
#   ('ECM1', 'GCNT3'),
#   ('CXCL2', 'CXCL8'),
#   ('MX2', 'SLC15A3'),
#   ('IFIT3', 'STAT1'),
#   ('IFITM1', 'LAMP3'),
#   ('LSP1', 'TXLNGY'),
#   ('SAA2-SAA4', 'TGM2'),
#   ('SERPINA3', 'TGM2'),
#   ('CSTA', 'S100A8'),
#   ('HLA-DOA', 'TNNT3'),
#   ('CXCL10', 'CXCL11'),
#   ('GMPR', 'SLC15A3'),
#   ('DDIT3', 'PLAU'),
#   ('CSPG4P10', 'TF'),
#   ('KRT13', 'KRT4'),
#   ('DUOXA2', 'STAT1'),
#   ('CSTA', 'EMP1'),
#   ('LAMP3', 'MX1'),
#   ('CES1', 'LOC107987423'),
#   ('PLA2G10BP', 'TRIM5'),
#   ('LOC128125814', 'THBS1'),
#   ('PTN', 'ZFY'),
#   ('IFIT1', 'OAS2'),
#   ('PLAU', 'PTGS2'),
#   ('LOC124903629', 'PROS1'),
#   ('CAPN9', 'TGM2'),
#   ('EPSTI1', 'TRIM5'),
#   ('EPSTI1', 'STAT1'),
#   ('IFIT3', 'LAMP3'),
#   ('IFIT2', 'MX1'),
#   ('ISG15', 'OAS3'),
#   ('IFI44L', 'STAT1'),
#   ('RBP1', 'RNASE1'),
#   ('IER5L', 'TLR2'),
#   ('IFITM1', 'MX1'),
#   ('DOC2A', 'PRODH'),
#   ('IFIT1', 'ISG15'),
#   ('MX2', 'SAMD9L'),
#   ('KCNMA1', 'NOS2'),
#   ('C1S', 'PTGS2'),
#   ('NOS2', 'PTPRT'),
#   ('CHP2', 'U6'),
#   ('PIP', 'TGM2'),
#   ('CES1', 'KDM5D'),
#   ('GTF2H2C', 'RBP1'),
#   ('HGD', 'HLA-L'),
#   ('CXCL14', 'THBS1'),
#   ('CA12', 'LDHAP4'),
#   ('IFIT3', 'OASL'),
#   ('LDHAP4', 'RBP1'),
#   ('LSP1', 'UTY'),
#   ('CD14', 'NOS2'),
#   ('MX1', 'OAS1'),
#   ('COL28A1', 'LSP1'),
#   ('TAGLN', 'THBS1'),
#   ('ISG15', 'SAMD9'),
#   ('CXCL8', 'S100A7'),
#   ('HP', 'TGM2'),
#   ('CXCL8', 'RARRES1'),
#   ('SMIM6', 'TNNT3'),
#   ('CMPK2', 'ISG15'),
#   ('MX1', 'OAS2'),
#   ('HSH2D', 'MX1'),
#   ('NKX2-1', 'NOS2'),
#   ('LOC102724428', 'RBP1'),
#   ('FKBP6P1', 'LSP1'),
#   ('RPS14P8', 'TNNT3'),
#   ('RPS14P8', 'TF')],
#  'PIDC': [('CXCL10', 'CXCL11'),
#   ('ISG15', 'SAMD9L'),
#   ('ISG15', 'RSAD2'),
#   ('ISG15', 'TF'),
#   ('RSAD2', 'TF'),
#   ('CXCL8', 'OAS3'),
#   ('PRODH', 'SERPINA1'),
#   ('CROCCP2', 'PROS1'),
#   ('STAT1', 'U6'),
#   ('GMPR', 'U6'),
#   ('TLR2', 'U6'),
#   ('MX1', 'U6'),
#   ('IFIT3', 'U6'),
#   ('RBP1', 'U6'),
#   ('CXCL8', 'MX2'),
#   ('CCN1', 'FOS'),
#   ('LSP1P2', 'MX1'),
#   ('GMPR', 'LSP1P2'),
#   ('LSP1P2', 'RBP1'),
#   ('LSP1P2', 'TLR2'),
#   ('IFIT3', 'LSP1P2'),
#   ('LSP1P2', 'STAT1'),
#   ('GMPR', 'PTGS2'),
#   ('PTGS2', 'STAT1'),
#   ('CD68', 'PTGS2'),
#   ('MX1', 'PTGS2'),
#   ('IFIT2', 'PTGS2'),
#   ('PIP', 'PTGS2'),
#   ('DDX60', 'PTGS2'),
#   ('PTGS2', 'TLR2'),
#   ('FCGBP', 'PTGS2'),
#   ('OAS2', 'PTGS2'),
#   ('PTGS2', 'RBP1'),
#   ('PTGS2', 'TCN1'),
#   ('IFIT3', 'PTGS2'),
#   ('PTGS2', 'SULF2'),
#   ('PTGS2', 'SAMD9'),
#   ('MT1P3', 'STAT1'),
#   ('MT1P3', 'MX1'),
#   ('MT1P3', 'TLR2'),
#   ('IFIT3', 'MT1P3'),
#   ('MT1P3', 'RBP1'),
#   ('GMPR', 'MT1P3'),
#   ('GMPR', 'SNORD89'),
#   ('SNORD89', 'STAT1'),
#   ('SNORD89', 'TLR2'),
#   ('IFIT3', 'SNORD89'),
#   ('RBP1', 'SNORD89'),
#   ('MX1', 'SNORD89'),
#   ('5S_rRNA', 'MX1'),
#   ('5S_rRNA', 'GMPR'),
#   ('5S_rRNA', 'IFIT3'),
#   ('5S_rRNA', 'RBP1'),
#   ('5S_rRNA', 'TLR2'),
#   ('5S_rRNA', 'STAT1'),
#   ('ISG15', 'MX2'),
#   ('GSTA3', 'HGD'),
#   ('GMPR', 'IDO1'),
#   ('IDO1', 'IFIT3'),
#   ('IDO1', 'TLR2'),
#   ('IDO1', 'RBP1'),
#   ('IDO1', 'STAT1'),
#   ('IDO1', 'MX1'),
#   ('RBP1', 'RNVU1-7'),
#   ('RNVU1-7', 'TLR2'),
#   ('GMPR', 'RNVU1-7'),
#   ('RNVU1-7', 'STAT1'),
#   ('MX1', 'RNVU1-7'),
#   ('IFIT3', 'RNVU1-7'),
#   ('KRT16', 'RBP1'),
#   ('KRT16', 'STAT1'),
#   ('IFIT3', 'KRT16'),
#   ('KRT16', 'TLR2'),
#   ('GMPR', 'KRT16'),
#   ('KRT16', 'MX1'),
#   ('APOBEC3A_B', 'IFIT3'),
#   ('APOBEC3A_B', 'GMPR'),
#   ('APOBEC3A_B', 'RBP1'),
#   ('APOBEC3A_B', 'STAT1'),
#   ('APOBEC3A_B', 'TLR2'),
#   ('APOBEC3A_B', 'MX1'),
#   ('RBP1', 'VMO1'),
#   ('MX1', 'VMO1'),
#   ('IFIT3', 'VMO1'),
#   ('GMPR', 'VMO1'),
#   ('TLR2', 'VMO1'),
#   ('STAT1', 'VMO1'),
#   ('MMP9', 'MX1'),
#   ('MMP9', 'TLR2'),
#   ('GMPR', 'MMP9'),
#   ('MMP9', 'STAT1'),
#   ('IFIT3', 'MMP9'),
#   ('MMP9', 'RBP1'),
#   ('CACNG6', 'STAT1'),
#   ('CACNG6', 'IFIT3'),
#   ('CACNG6', 'GMPR'),
#   ('CACNG6', 'MX1'),
#   ('CACNG6', 'TLR2'),
#   ('CACNG6', 'RBP1'),
#   ('GTF2H2C', 'RBP1'),
#   ('GTF2H2C', 'TLR2'),
#   ('GTF2H2C', 'STAT1'),
#   ('GTF2H2C', 'IFIT3'),
#   ('GMPR', 'GTF2H2C'),
#   ('GTF2H2C', 'MX1'),
#   ('MX2', 'OASL'),
#   ('LOC124900276', 'STAT1'),
#   ('IFIT3', 'LOC124900276'),
#   ('LOC124900276', 'MX1'),
#   ('LOC124900276', 'RBP1'),
#   ('LOC124900276', 'TLR2'),
#   ('GMPR', 'LOC124900276'),
#   ('PKD1P2', 'RBP1'),
#   ('PKD1P2', 'STAT1'),
#   ('GMPR', 'PKD1P2'),
#   ('PKD1P2', 'TLR2'),
#   ('IFIT3', 'PKD1P2'),
#   ('MX1', 'PKD1P2'),
#   ('IFIT3', 'PLAU'),
#   ('PLAU', 'TLR2'),
#   ('PLAU', 'STAT1'),
#   ('PLAU', 'RBP1'),
#   ('GMPR', 'PLAU'),
#   ('MX1', 'PLAU'),
#   ('PIGY', 'TLR2'),
#   ('GMPR', 'PIGY'),
#   ('PIGY', 'STAT1'),
#   ('IFIT3', 'PIGY'),
#   ('PIGY', 'RBP1'),
#   ('MX1', 'PIGY'),
#   ('MX2', 'RSAD2'),
#   ('IFIT3', 'LOC107987423'),
#   ('LOC107987423', 'STAT1'),
#   ('LOC107987423', 'TLR2'),
#   ('GMPR', 'LOC107987423'),
#   ('LOC107987423', 'RBP1'),
#   ('LOC107987423', 'MX1'),
#   ('CXCL2', 'GMPR'),
#   ('CXCL2', 'RBP1'),
#   ('CXCL2', 'TLR2'),
#   ('CXCL2', 'IFIT3'),
#   ('CXCL2', 'STAT1'),
#   ('CXCL2', 'MX1'),
#   ('CFAP210', 'PROS1'),
#   ('DDIT3', 'GADD45B'),
#   ('LOC124903629', 'PROS1'),
#   ('MX2', 'OAS3'),
#   ('IFI44L', 'IFITM1'),
#   ('IFIT1', 'IFITM1'),
#   ('ECM1', 'SPRR3'),
#   ('C1S', 'FOS'),
#   ('MT1P3', 'MYOM2'),
#   ('OAS3', 'TRIM5'),
#   ('HOTAIRM1', 'PROS1'),
#   ('MX2', 'TF'),
#   ('DUOXA2', 'MX2'),
#   ('OASL', 'TF'),
#   ('CSPG4P10', 'TF'),
#   ('EPSTI1', 'ISG15'),
#   ('HLA-DRB5', 'PTN'),
#   ('AQP5', 'THBS1'),
#   ('DDIT3', 'PLAU'),
#   ('HLA-DOA', 'TNNT3'),
#   ('KCNMA1', 'MAN1C1'),
#   ('CA12', 'HP'),
#   ('DUOX2', 'MX2'),
#   ('CXCL8', 'PTGS2'),
#   ('A2ML1', 'CSTA'),
#   ('KRT14', 'KRT6A'),
#   ('CMPK2', 'IFITM1'),
#   ('GCNT3', 'THBS1'),
#   ('CXCL8', 'SLC15A3'),
#   ('IFITM1', 'LAMP3')]}

# %%
pidc_set = set(found_interactions['PIDC'])
genie3_set = set(found_interactions['GENIE3'])
grn_set = set(found_interactions['GRNBoost2'])

# Create Venn diagram
venn3([pidc_set, genie3_set
       , grn_set
      ], 
      set_labels=('PIDC Known Interactions', 'GENIE3 Known Interactions'
                 , 'GRNBoost2 Known Interactions'
                 ))

plt.title('BioGRID Verified Interactions for Top 500')

# Show plot
plt.show()
